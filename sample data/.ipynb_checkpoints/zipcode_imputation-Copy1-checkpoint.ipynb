# %%
import pandas as pd
import numpy as np
import geopy
# https://gis.stackexchange.com/questions/330840/error-installing-geopandas
# conda install -c conda-forge geopandas

import geopandas as gpd
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import matplotlib.pyplot as plt
from shapely.geometry import point
from geopandas import GeoDataFrame
import plotly_express as px

#from uszipcode import ZipcodeSearchEngine
from uszipcode import SearchEngine

pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 300)

# %%
#longlat = pd.read_csv("longlat.csv",encoding = 'utf-8', sep = '\t')
df =pd.read_csv("C://CompletePython//DataScience/VisionZero//2016/crashes_datetime6.csv")
df.head(3)
# Out:
#    Unnamed: 0  Unnamed: 0.1       crash_date_new person_type person_injury  \
# 0           0             0  2019-10-26 00:00:00    OCCUPANT   NOT INJURED
# 1           1             8  2019-10-26 00:00:00    OCCUPANT   NOT INJURED
# 2           2             9  2019-10-26 00:00:00    OCCUPANT   NOT INJURED
#
#    person_age     ejection position_in_vehicle    safety_equipment ped_role  \
# 0        52.0  NOT EJECTED              DRIVER  LAP BELT & HARNESS   DRIVER
# 1        41.0  NOT EJECTED              DRIVER            LAP BELT   DRIVER
# 2        35.0  NOT EJECTED              DRIVER            LAP BELT   DRIVER
#
#   person_sex vehicle_type vehicle_make vehicle_year vehicle_occupants  \
# 0          M  UNSPECIFIED  UNSPECIFIED  UNSPECIFIED       UNSPECIFIED
# 1          M  UNSPECIFIED  UNSPECIFIED  UNSPECIFIED       UNSPECIFIED
# 2          M  UNSPECIFIED  UNSPECIFIED  UNSPECIFIED       UNSPECIFIED
#
#   driver_sex driver_license_status     pre_crash point_of_impact  \
# ...

# %%
df.drop(['crash_date_new', 'Unnamed: 0', 'Unnamed: 0.1'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   person_type person_injury  person_age     ejection  \
# 0    OCCUPANT   NOT INJURED        52.0  NOT EJECTED
# 1    OCCUPANT   NOT INJURED        41.0  NOT EJECTED
# 2    OCCUPANT   NOT INJURED        35.0  NOT EJECTED
# 3    OCCUPANT   NOT INJURED        17.0  NOT EJECTED
# 4    OCCUPANT       INJURED        26.0  NOT EJECTED
#
#                                  position_in_vehicle    safety_equipment  \
# 0                                             DRIVER  LAP BELT & HARNESS
# 1                                             DRIVER            LAP BELT
# 2                                             DRIVER            LAP BELT
# 3  RIGHT REAR PASSENGER OR MOTORCYCLE SIDECAR PAS...  LAP BELT & HARNESS
# 4  FRONT PASSENGER, IF TWO OR MORE PERSONS, INCLU...  LAP BELT & HARNESS
#
#     ped_role person_sex vehicle_type vehicle_make vehicle_year  \
# 0     DRIVER          M  UNSPECIFIED  UNSPECIFIED  UNSPECIFIED
# 1     DRIVER          M  UNSPECIFIED  UNSPECIFIED  UNSPECIFIED
# ...
