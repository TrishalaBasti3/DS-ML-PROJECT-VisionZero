# %%
import pandas as pd
import numpy as np
import math
import datetime

# To see all the columns 
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 600)

# %%
#df= pd.read_csv("C:\\CompletePython\\DataScience\VisionZero\\2016\\crashes_datetime2.csv")
df = pd.read_csv("C:\\CompletePython\\DataScience\VisionZero\\2016\\crashes_datetime2.csv",
                 parse_dates= {"crash_date_new" : ["crash_date_year","crash_date_month","crash_date_day"]},
                keep_date_col=True)

# %%
df['crash_time'] = pd.to_datetime(df.crash_time)

# %%
df['Time'] = [d.time() for d in df['crash_time']]

# %%
df.head(2)
# Out:
#   crash_date_new  Unnamed: 0  Unnamed: 0.1           crash_date  \
# 0     2019-10-26           2             2  2019-10-26 00:00:00
# 1     2019-10-23           3             3  2019-10-23 00:00:00
#
#            crash_time person_type person_injury  person_age     ejection  \
# 0 2021-11-17 16:30:00    OCCUPANT   NOT INJURED        52.0  NOT EJECTED
# 1 2021-11-17 15:00:00    OCCUPANT   NOT INJURED        38.0  NOT EJECTED
#
#   position_in_vehicle    safety_equipment ped_role person_sex vehicle_type  \
# 0              DRIVER  LAP BELT & HARNESS   DRIVER          M  UNSPECIFIED
# 1             UNKNOWN             UNKNOWN   DRIVER          M  UNSPECIFIED
#
#   vehicle_make vehicle_year vehicle_occupants driver_sex  \
# 0  UNSPECIFIED  UNSPECIFIED       UNSPECIFIED          M
# 1  UNSPECIFIED  UNSPECIFIED       UNSPECIFIED          M
#
#   driver_license_status     pre_crash point_of_impact vehicle_damage  \
# 0           UNSPECIFIED  NOT_AVALIBLE    NOT_AVALIBLE   NOT_AVALIBLE
# ...

# %%
df.loc[:,'completedate'] = pd.to_datetime(df.	crash_date_new.astype(str)+' '+df.Time.astype(str))

# %%
df.head(2)
# Out:
#   crash_date_new  Unnamed: 0  Unnamed: 0.1           crash_date  \
# 0     2019-10-26           2             2  2019-10-26 00:00:00
# 1     2019-10-23           3             3  2019-10-23 00:00:00
#
#            crash_time person_type person_injury  person_age     ejection  \
# 0 2021-11-17 16:30:00    OCCUPANT   NOT INJURED        52.0  NOT EJECTED
# 1 2021-11-17 15:00:00    OCCUPANT   NOT INJURED        38.0  NOT EJECTED
#
#   position_in_vehicle    safety_equipment ped_role person_sex vehicle_type  \
# 0              DRIVER  LAP BELT & HARNESS   DRIVER          M  UNSPECIFIED
# 1             UNKNOWN             UNKNOWN   DRIVER          M  UNSPECIFIED
#
#   vehicle_make vehicle_year vehicle_occupants driver_sex  \
# 0  UNSPECIFIED  UNSPECIFIED       UNSPECIFIED          M
# 1  UNSPECIFIED  UNSPECIFIED       UNSPECIFIED          M
#
#   driver_license_status     pre_crash point_of_impact vehicle_damage  \
# 0           UNSPECIFIED  NOT_AVALIBLE    NOT_AVALIBLE   NOT_AVALIBLE
# ...

# %%
df=df.drop(['Unnamed: 0','Unnamed: 0.1','crash_date', 'crash_time'], axis=1)

# %%
df = df[df['on_street_name'].notna()]

# %%
df.head(3)
# Out:
#   crash_date_new person_type person_injury  person_age     ejection  \
# 0     2019-10-26    OCCUPANT   NOT INJURED        52.0  NOT EJECTED
# 8     2019-10-26    OCCUPANT   NOT INJURED        41.0  NOT EJECTED
# 9     2019-10-26    OCCUPANT   NOT INJURED        35.0  NOT EJECTED
#
#   position_in_vehicle    safety_equipment ped_role person_sex vehicle_type  \
# 0              DRIVER  LAP BELT & HARNESS   DRIVER          M  UNSPECIFIED
# 8              DRIVER            LAP BELT   DRIVER          M  UNSPECIFIED
# 9              DRIVER            LAP BELT   DRIVER          M  UNSPECIFIED
#
#   vehicle_make vehicle_year vehicle_occupants driver_sex  \
# 0  UNSPECIFIED  UNSPECIFIED       UNSPECIFIED          M
# 8  UNSPECIFIED  UNSPECIFIED       UNSPECIFIED          M
# 9  UNSPECIFIED  UNSPECIFIED       UNSPECIFIED          M
#
#   driver_license_status     pre_crash point_of_impact vehicle_damage  \
# 0           UNSPECIFIED  NOT_AVALIBLE    NOT_AVALIBLE   NOT_AVALIBLE
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# crash_date_new                     0
# person_type                        0
# Time                               0
# crash_date_day                     0
# crash_date_month                   0
# crash_date_year                    0
# number_of_contributing_vehicles    0
# collision_id                       0
# on_street_name                     0
# longitude                          0
# latitude                           0
# zip_code                           0
# borough                            0
# contributing_factor_2              0
# contributing_factor_1              0
# vehicle_damage                     0
# point_of_impact                    0
# pre_crash                          0
# driver_license_status              0
# driver_sex                         0
# vehicle_occupants                  0
# vehicle_year                       0
# vehicle_make                       0
# vehicle_type                       0
# person_sex                         0
# ...

# %%
df.to_csv("C:\\CompletePython\\DataScience\VisionZero\\2016\\crashes_datetime5.csv",header=True)
